# %% [markdown]
# ## Lab 1: Data in Python
#
# The data for this activity can be downloaded here (under "Data Sets"): https://www.statlearning.com/resources-python

# %% [markdown]
# As a first step, create a folder in this location called "data" and drop the Credit.csv file in that location.
#
# If you open the ".gitignore" file, you'll notice that one of the entries is "data" so that your data files will not be shared on GitHub.

# %%
# !pip install pandas
# !pip install numpy

# %%
import pandas as pd
import numpy as np
Credit = pd.read_csv('data/Credit.csv')
Credit
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Own Student Married  \
# 0     14.891   3606     283      2   34         11   No      No     Yes
# 1    106.025   6645     483      3   82         15  Yes     Yes     Yes
# 2    104.593   7075     514      4   71         11   No      No      No
# 3    148.924   9504     681      3   36         11  Yes      No      No
# 4     55.882   4897     357      2   68         16   No      No     Yes
# ..       ...    ...     ...    ...  ...        ...  ...     ...     ...
# 395   12.096   4100     307      3   32         13   No      No     Yes
# 396   13.364   3838     296      5   65         17   No      No      No
# 397   57.872   4171     321      5   67         12  Yes      No     Yes
# 398   37.728   2525     192      1   44         13   No      No     Yes
# 399   18.701   5524     415      5   64          7  Yes      No      No
#
#     Region  Balance
# 0    South      333
# 1     West      903
# 2     West      580
# 3     West      964
# 4    South      331
# ..     ...      ...
# 395  South      560
# 396   East      480
# 397  South      138
# 398  South        0
# 399   West      966
#
# [400 rows x 11 columns]

# %% [markdown]
# ### What are the feature names?

# %% [markdown]
# Income, Limit, Rating, Cards, Age, Education, Own, Student, Married, Region, and Balance

# %% [markdown]
# ### What are the data types of the feature values (i.e., numeric, categorical)

# %% [markdown]
# Income : Numeric, Limit : Numeric, Rating : Numeric, Cards : Numeric, Age : Numeric, Education : Numeric, Own: Binary, Student : Binary, Married: Binary, Region : Categorical, Balance : Numeric

# %% [markdown]
# ### Find the mean, median, and mode of the feature "Age."

# %%
# mean 
Credit["Age"].mean()
# Out:
# np.float64(55.6675)

# %%
# median
Credit["Age"].median()
# Out:
# np.float64(56.0)

# %%
# mode
Credit["Age"].mode()
# Out:
# 0    44
# 1    66
# Name: Age, dtype: int64

# %% [markdown]
# ### Create a subset of Credit that only contains the columns Age, Region, and Income. Call it "Subset."

# %%
Subset = Credit[["Age", "Region", "Income"]]
Subset
# Out:
#      Age Region   Income
# 0     34  South   14.891
# 1     82   West  106.025
# 2     71   West  104.593
# 3     36   West  148.924
# 4     68  South   55.882
# ..   ...    ...      ...
# 395   32  South   12.096
# 396   65   East   13.364
# 397   67  South   57.872
# 398   44  South   37.728
# 399   64   West   18.701
#
# [400 rows x 3 columns]

# %% [markdown]
# ### From this subset, create two partitions:
# - One that contains records for Ages below 50, and one that contains Ages 50+
# - Call them "Younger" and "Older"

# %%
Younger = Credit[Credit["Age"]<50]
Younger
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Own Student Married  \
# 0     14.891   3606     283      2   34         11   No      No     Yes
# 3    148.924   9504     681      3   36         11  Yes      No      No
# 6     20.996   3388     259      2   37         12  Yes      No      No
# 9     71.061   6819     491      3   41         19  Yes     Yes     Yes
# 10    63.095   8117     589      4   30         14   No      No     Yes
# ..       ...    ...     ...    ...  ...        ...  ...     ...     ...
# 391   73.327   6555     472      2   43         15  Yes      No      No
# 392   25.974   2308     196      2   24         10   No      No      No
# 394   49.794   5758     410      4   40          8   No      No      No
# 395   12.096   4100     307      3   32         13   No      No     Yes
# 398   37.728   2525     192      1   44         13   No      No     Yes
#
#     Region  Balance
# 0    South      333
# 3     West      964
# 6     East      203
# 9     East     1350
# 10   South     1407
# ..     ...      ...
# 391  South      721
# 392   West        0
# 394  South      734
# 395  South      560
# 398  South        0
#
# [161 rows x 11 columns]

# %%
Older = Credit[Credit["Age"]>=50]
Older
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Own Student Married  \
# 1    106.025   6645     483      3   82         15  Yes     Yes     Yes
# 2    104.593   7075     514      4   71         11   No      No      No
# 4     55.882   4897     357      2   68         16   No      No     Yes
# 5     80.180   8047     569      4   77         10   No      No      No
# 7     71.408   7114     512      2   87          9   No      No      No
# ..       ...    ...     ...    ...  ...        ...  ...     ...     ...
# 390  135.118  10578     747      3   81         15  Yes      No     Yes
# 393   17.316   1335     138      2   65         13   No      No      No
# 396   13.364   3838     296      5   65         17   No      No      No
# 397   57.872   4171     321      5   67         12  Yes      No     Yes
# 399   18.701   5524     415      5   64          7  Yes      No      No
#
#     Region  Balance
# 1     West      903
# 2     West      580
# 4    South      331
# 5    South     1151
# 7     West      872
# ..     ...      ...
# 390   West     1393
# 393   East        0
# 396   East      480
# 397  South      138
# 399   West      966
#
# [239 rows x 11 columns]

# %% [markdown]
# ### Use these partitions to compare the mean and median Income for each age group (less than 50 vs. 50+)

# %%
# mean of younger
Younger["Income"].mean()
# Out:
# np.float64(41.65203726708074)

# %%
# mean of older
Older["Income"].mean()
# Out:
# np.float64(47.6216569037657)

# %%
# median of younger
Younger["Income"].median()
# Out:
# np.float64(31.861)

# %%
# median of older
Older["Income"].median()
# Out:
# np.float64(33.694)

# %% [markdown]
# ### What does the difference between mean and median suggest about the distribution of income?

# %% [markdown]
# It's skewed to the right, since the Mean is higher compared to the Median.

# %% [markdown]
# ### What are the possible values for Region?

# %%
Credit["Region"].unique()
# Out:
# <StringArray>
# ['South', 'West', 'East']
# Length: 3, dtype: str

# %% [markdown]
# ### Use the value_counts method to build a frequency table for the possible values of Region.

# %%
Credit["Region"].value_counts()
# Out:
# Region
# South    199
# West     102
# East      99
# Name: count, dtype: int64

# %% [markdown]
# ### Compare the average income for students vs. non-students.

# %%
Student = Credit[Credit["Student"]=="Yes"]
Student.head()
# Out:
#      Income  Limit  Rating  Cards  Age  Education  Own Student Married Region  \
# 1   106.025   6645     483      3   82         15  Yes     Yes     Yes   West
# 9    71.061   6819     491      3   41         19  Yes     Yes     Yes   East
# 26   42.471   3625     289      6   44         12  Yes     Yes      No  South
# 35   23.350   2558     220      3   49         12  Yes     Yes      No  South
# 41  113.659   7659     538      2   66         15   No     Yes     Yes   East
#
#     Balance
# 1       903
# 9      1350
# 26      654
# 35      419
# 41     1155

# %%
NonStudent = Credit[Credit["Student"]=="No"]
NonStudent.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Own Student Married Region  \
# 0   14.891   3606     283      2   34         11   No      No     Yes  South
# 2  104.593   7075     514      4   71         11   No      No      No   West
# 3  148.924   9504     681      3   36         11  Yes      No      No   West
# 4   55.882   4897     357      2   68         16   No      No     Yes  South
# 5   80.180   8047     569      4   77         10   No      No      No  South
#
#    Balance
# 0      333
# 2      580
# 3      964
# 4      331
# 5     1151

# %%
Student["Income"].mean()
# Out:
# np.float64(47.29205)

# %%
NonStudent["Income"].mean()
# Out:
# np.float64(44.988533333333336)

# %% [markdown]
# Students get paid more in general.

# %% [markdown]
# Often, banks will use a variable called _utilization_ to assess credit risk.
# Utilization is the ratio of balance to limit (i.e., what % of the credit limit is being used?)
# ### Add a feature to the Credit dataset to measure utilization

# %%
Credit["Utilization"] = Credit["Balance"]/Credit["Limit"]
Credit
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Own Student Married  \
# 0     14.891   3606     283      2   34         11   No      No     Yes
# 1    106.025   6645     483      3   82         15  Yes     Yes     Yes
# 2    104.593   7075     514      4   71         11   No      No      No
# 3    148.924   9504     681      3   36         11  Yes      No      No
# 4     55.882   4897     357      2   68         16   No      No     Yes
# ..       ...    ...     ...    ...  ...        ...  ...     ...     ...
# 395   12.096   4100     307      3   32         13   No      No     Yes
# 396   13.364   3838     296      5   65         17   No      No      No
# 397   57.872   4171     321      5   67         12  Yes      No     Yes
# 398   37.728   2525     192      1   44         13   No      No     Yes
# 399   18.701   5524     415      5   64          7  Yes      No      No
#
#     Region  Balance  Utilization
# 0    South      333     0.092346
# 1     West      903     0.135892
# 2     West      580     0.081979
# 3     West      964     0.101431
# 4    South      331     0.067592
# ..     ...      ...          ...
# 395  South      560     0.136585
# 396   East      480     0.125065
# 397  South      138     0.033086
# 398  South        0     0.000000
# 399   West      966     0.174873
#
# [400 rows x 12 columns]

# %% [markdown]
# ### What is the maximum utilization value in this set?

# %%
Credit["Utilization"].max()
# Out:
# np.float64(0.27693008426326576)
